# %%
# Import packages
import pandas as pd, numpy as np
import os, sys, glob, re
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %%
inputfolder = Path(r'C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\data\Dafne CSV Raw Data')
outputfolder_fragments = Path(r'C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\fragments')
outputfolder_combined = Path(r'C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\combined')
colnamesfilepath = Path(r'C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\data\examples\Dafne_Check_2.xlsx')

# %%
# Get list of files to combine
inputfilename_list = os.listdir(inputfolder)
print("Number of files:", len(inputfilename_list))
# Out:
# Number of files: 678

# %% [markdown]
# # Define column names

# %%
def process_colnames(colnames, replacements):
    for replacement in replacements:
        colnames = colnames.str.replace(replacement[0], replacement[1], regex=False)
    return colnames

# %%
# Get column names
df_colnames = pd.read_excel(colnamesfilepath, sheet_name=1)
colnames = df_colnames.columns
colnames = colnames.str.replace('\n',' ')
colnames = colnames.str.lower()
colnames = colnames[1:] # Drop the first column, which is just an index column

# Process column names to comply with Stata requirements:
# strings only, max 32 characters, only alphanumerics and underscores, no Stata reserved words
replacements = [[',', ''], [' ', '_'] , ['/_', ''], ['(tc)_', ''], ['th_eur_', ''], ['.1', '_1'], ['/', '_'], ['-_', ''],
                ['up_to_1_year', '0_1_yr'], ['1_to_5_years', '1_5_yr'], ['more_than_1_and_up_to_5_years', '1_5_yr'], 
                ['thereof', 'thof'], ['primary_activity_code', 'pri_actv_cd'],
                ['above_5_years', '5_plus_yr'], ['more_than_5_years', '5_plus_yr'], 
                ['more_than_1_year', '1_plus_yr'], ['for_the_year_', ''], ['from', 'fr'], 
                ['(corporates)_', ''], ['shareholder', 'shhldr'], ['share', 'sh'], ['capital', 'cap'], ['account', 'acct'],
                ['interest', 'int'], ['ordinary', 'ord'], ['activities', 'actvs'], ['subscribed', 'subd'], ['liabilities', 'liabs'],
                ['cost_of_raw_materials_consumables_and_supplies_and_of_purchased_merchandise', 'cost_of_raw_materials'],
                ['increase_or_decrease_in', 'inc_or_dec'], ['stocks_of_animals', 'stocks_animals'],
                ['finished_goods_inventories_and_work_in_process', 'fin_gds_inv'],
                ['bank_deposits_and_fr_receivables_to_third_parties', 'bank_deposits']]
colnames = process_colnames(colnames, replacements)

# View processed column names
for i in colnames:
    print(i)
# Out:
# company_name
# crefo_number
# gkz_administrative_region_code
# gkz_borough_code
# wz_2008_pri_actv_cd_1_digit
# wz_2008_pri_actv_cd_3_digits
# original_date_of_incorporation
# listed_delisted_unlisted
# peer_group_name
# peer_group_description
# number_of_employees_2014
# number_of_employees_2013
# number_of_employees_2012
# number_of_employees_2011
# number_of_employees_2010
# number_of_employees_2009
# number_of_employees_2008
# number_of_employees_2007
# number_of_employees_2006
# number_of_employees_2005
# tangible_assets_2014
# tangible_assets_2013
# tangible_assets_2012
# tangible_assets_2011
# tangible_assets_2010
# tangible_assets_2009
# tangible_assets_2008
# tangible_assets_2007
# tangible_assets_2006
# tangible_assets_2005
# on_tangible_assets_2014
# on_tangible_assets_2013
# on_tangible_assets_2012
# on_tangible_assets_2011
# on_tangible_assets_2010
# on_tangible_assets_2009
# on_tangible_assets_2008
# on_tangible_assets_2007
# on_tangible_assets_2006
# on_tangible_assets_2005
# gross_results_2014
# gross_results_2013
# gross_results_2012
# gross_results_2011
# gross_results_2010
# gross_results_2009
# gross_results_2008
# gross_results_2007
# gross_results_2006
# gross_results_2005
# cost_of_materials_2014
# cost_of_materials_2013
# cost_of_materials_2012
# cost_of_materials_2011
# cost_of_materials_2010
# cost_of_materials_2009
# cost_of_materials_2008
# cost_of_materials_2007
# cost_of_materials_2006
# cost_of_materials_2005
# cost_of_raw_materials_2014
# cost_of_raw_materials_2013
# cost_of_raw_materials_2012
# cost_of_raw_materials_2011
# cost_of_raw_materials_2010
# cost_of_raw_materials_2009
# cost_of_raw_materials_2008
# cost_of_raw_materials_2007
# cost_of_raw_materials_2006
# cost_of_raw_materials_2005
# personnel_expenses_2014
# personnel_expenses_2013
# personnel_expenses_2012
# personnel_expenses_2011
# personnel_expenses_2010
# personnel_expenses_2009
# personnel_expenses_2008
# personnel_expenses_2007
# personnel_expenses_2006
# personnel_expenses_2005
# wages_and_salaries_2014
# wages_and_salaries_2013
# wages_and_salaries_2012
# wages_and_salaries_2011
# wages_and_salaries_2010
# wages_and_salaries_2009
# wages_and_salaries_2008
# wages_and_salaries_2007
# wages_and_salaries_2006
# wages_and_salaries_2005
# loans_2014
# loans_2013
# loans_2012
# loans_2011
# loans_2010
# loans_2009
# loans_2008
# loans_2007
# loans_2006
# loans_2005
# liabs_2014
# liabs_2013
# liabs_2012
# liabs_2011
# liabs_2010
# liabs_2009
# liabs_2008
# liabs_2007
# liabs_2006
# liabs_2005
# thof_0_1_yr_2014
# thof_0_1_yr_2013
# thof_0_1_yr_2012
# thof_0_1_yr_2011
# thof_0_1_yr_2010
# thof_0_1_yr_2009
# thof_0_1_yr_2008
# thof_0_1_yr_2007
# thof_0_1_yr_2006
# thof_0_1_yr_2005
# thof_1_5_yr_2014
# thof_1_5_yr_2013
# thof_1_5_yr_2012
# thof_1_5_yr_2011
# thof_1_5_yr_2010
# thof_1_5_yr_2009
# thof_1_5_yr_2008
# thof_1_5_yr_2007
# thof_1_5_yr_2006
# thof_1_5_yr_2005
# thof_5_plus_yr_2014
# thof_5_plus_yr_2013
# thof_5_plus_yr_2012
# thof_5_plus_yr_2011
# thof_5_plus_yr_2010
# thof_5_plus_yr_2009
# thof_5_plus_yr_2008
# thof_5_plus_yr_2007
# thof_5_plus_yr_2006
# thof_5_plus_yr_2005
# thof_liabs_to_shhldrs_2014
# thof_liabs_to_shhldrs_2013
# thof_liabs_to_shhldrs_2012
# thof_liabs_to_shhldrs_2011
# thof_liabs_to_shhldrs_2010
# thof_liabs_to_shhldrs_2009
# thof_liabs_to_shhldrs_2008
# thof_liabs_to_shhldrs_2007
# thof_liabs_to_shhldrs_2006
# thof_liabs_to_shhldrs_2005
# liabs_to_banks_2014
# liabs_to_banks_2013
# liabs_to_banks_2012
# liabs_to_banks_2011
# liabs_to_banks_2010
# liabs_to_banks_2009
# liabs_to_banks_2008
# liabs_to_banks_2007
# liabs_to_banks_2006
# liabs_to_banks_2005
# with_a_term_0_1_yr_2014
# with_a_term_0_1_yr_2013
# with_a_term_0_1_yr_2012
# with_a_term_0_1_yr_2011
# with_a_term_0_1_yr_2010
# with_a_term_0_1_yr_2009
# with_a_term_0_1_yr_2008
# with_a_term_0_1_yr_2007
# with_a_term_0_1_yr_2006
# with_a_term_0_1_yr_2005
# with_a_term_1_plus_yr_2014
# with_a_term_1_plus_yr_2013
# with_a_term_1_plus_yr_2012
# with_a_term_1_plus_yr_2011
# with_a_term_1_plus_yr_2010
# with_a_term_1_plus_yr_2009
# with_a_term_1_plus_yr_2008
# with_a_term_1_plus_yr_2007
# with_a_term_1_plus_yr_2006
# with_a_term_1_plus_yr_2005
# with_a_term_1_5_yr_2014
# with_a_term_1_5_yr_2013
# with_a_term_1_5_yr_2012
# with_a_term_1_5_yr_2011
# with_a_term_1_5_yr_2010
# with_a_term_1_5_yr_2009
# with_a_term_1_5_yr_2008
# with_a_term_1_5_yr_2007
# with_a_term_1_5_yr_2006
# with_a_term_1_5_yr_2005
# with_a_term_5_plus_yr_2014
# with_a_term_5_plus_yr_2013
# with_a_term_5_plus_yr_2012
# with_a_term_5_plus_yr_2011
# with_a_term_5_plus_yr_2010
# with_a_term_5_plus_yr_2009
# with_a_term_5_plus_yr_2008
# with_a_term_5_plus_yr_2007
# with_a_term_5_plus_yr_2006
# with_a_term_5_plus_yr_2005
# liabs_to_shhldrs_2014
# liabs_to_shhldrs_2013
# liabs_to_shhldrs_2012
# liabs_to_shhldrs_2011
# liabs_to_shhldrs_2010
# liabs_to_shhldrs_2009
# liabs_to_shhldrs_2008
# liabs_to_shhldrs_2007
# liabs_to_shhldrs_2006
# liabs_to_shhldrs_2005
# equity_2014
# equity_2013
# equity_2012
# equity_2011
# equity_2010
# equity_2009
# equity_2008
# equity_2007
# equity_2006
# equity_2005
# subd_cap_2014
# subd_cap_2013
# subd_cap_2012
# subd_cap_2011
# subd_cap_2010
# subd_cap_2009
# subd_cap_2008
# subd_cap_2007
# subd_cap_2006
# subd_cap_2005
# cap_reserves_2014
# cap_reserves_2013
# cap_reserves_2012
# cap_reserves_2011
# cap_reserves_2010
# cap_reserves_2009
# cap_reserves_2008
# cap_reserves_2007
# cap_reserves_2006
# cap_reserves_2005
# revenue_reserves_2014
# revenue_reserves_2013
# revenue_reserves_2012
# revenue_reserves_2011
# revenue_reserves_2010
# revenue_reserves_2009
# revenue_reserves_2008
# revenue_reserves_2007
# revenue_reserves_2006
# revenue_reserves_2005
# subd_cap_cap_acct_sh_in_cap_2014
# subd_cap_cap_acct_sh_in_cap_2013
# subd_cap_cap_acct_sh_in_cap_2012
# subd_cap_cap_acct_sh_in_cap_2011
# subd_cap_cap_acct_sh_in_cap_2010
# subd_cap_cap_acct_sh_in_cap_2009
# subd_cap_cap_acct_sh_in_cap_2008
# subd_cap_cap_acct_sh_in_cap_2007
# subd_cap_cap_acct_sh_in_cap_2006
# subd_cap_cap_acct_sh_in_cap_2005
# closing_date_2014
# closing_date_2013
# closing_date_2012
# closing_date_2011
# closing_date_2010
# closing_date_2009
# closing_date_2008
# closing_date_2007
# closing_date_2006
# closing_date_2005
# closing_date_2014_1
# closing_date_2013_1
# closing_date_2012_1
# closing_date_2011_1
# closing_date_2010_1
# closing_date_2009_1
# closing_date_2008_1
# closing_date_2007_1
# closing_date_2006_1
# closing_date_2005_1
# turnover_2014
# turnover_2013
# turnover_2012
# turnover_2011
# turnover_2010
# turnover_2009
# turnover_2008
# turnover_2007
# turnover_2006
# turnover_2005
# post_code
# city
# country
# last_entry_in_trade_register
# available_accts_2014
# available_accts_2013
# available_accts_2012
# available_accts_2011
# available_accts_2010
# available_accts_2009
# available_accts_2008
# available_accts_2007
# available_accts_2006
# available_accts_2005
# wz_2008_pri_actv_cd_4_digits
# us_sic_all_codes
# year_of_hgb_264
# isin_number
# cash_flow_2014
# cash_flow_2013
# cash_flow_2012
# cash_flow_2011
# cash_flow_2010
# cash_flow_2009
# cash_flow_2008
# cash_flow_2007
# cash_flow_2006
# cash_flow_2005
# results_fr_ord_actvs_2014
# results_fr_ord_actvs_2013
# results_fr_ord_actvs_2012
# results_fr_ord_actvs_2011
# results_fr_ord_actvs_2010
# results_fr_ord_actvs_2009
# results_fr_ord_actvs_2008
# results_fr_ord_actvs_2007
# results_fr_ord_actvs_2006
# results_fr_ord_actvs_2005
# operating_results_2014
# operating_results_2013
# operating_results_2012
# operating_results_2011
# operating_results_2010
# operating_results_2009
# operating_results_2008
# operating_results_2007
# operating_results_2006
# operating_results_2005
# total_output_2014
# total_output_2013
# total_output_2012
# total_output_2011
# total_output_2010
# total_output_2009
# total_output_2008
# total_output_2007
# total_output_2006
# total_output_2005
# depreciation_2014
# depreciation_2013
# depreciation_2012
# depreciation_2011
# depreciation_2010
# depreciation_2009
# depreciation_2008
# depreciation_2007
# depreciation_2006
# depreciation_2005
# fixed_assets_2014
# fixed_assets_2013
# fixed_assets_2012
# fixed_assets_2011
# fixed_assets_2010
# fixed_assets_2009
# fixed_assets_2008
# fixed_assets_2007
# fixed_assets_2006
# fixed_assets_2005
# intangible_assets_2014
# intangible_assets_2013
# intangible_assets_2012
# intangible_assets_2011
# intangible_assets_2010
# intangible_assets_2009
# intangible_assets_2008
# intangible_assets_2007
# intangible_assets_2006
# intangible_assets_2005
# inc_or_dec_fin_gds_inv_2014
# inc_or_dec_fin_gds_inv_2013
# inc_or_dec_fin_gds_inv_2012
# inc_or_dec_fin_gds_inv_2011
# inc_or_dec_fin_gds_inv_2010
# inc_or_dec_fin_gds_inv_2009
# inc_or_dec_fin_gds_inv_2008
# inc_or_dec_fin_gds_inv_2007
# inc_or_dec_fin_gds_inv_2006
# inc_or_dec_fin_gds_inv_2005
# inc_or_dec_stocks_animals_2014
# inc_or_dec_stocks_animals_2013
# inc_or_dec_stocks_animals_2012
# inc_or_dec_stocks_animals_2011
# inc_or_dec_stocks_animals_2010
# inc_or_dec_stocks_animals_2009
# inc_or_dec_stocks_animals_2008
# inc_or_dec_stocks_animals_2007
# inc_or_dec_stocks_animals_2006
# inc_or_dec_stocks_animals_2005
# net_income_net_loss_2014
# net_income_net_loss_2013
# net_income_net_loss_2012
# net_income_net_loss_2011
# net_income_net_loss_2010
# net_income_net_loss_2009
# net_income_net_loss_2008
# net_income_net_loss_2007
# net_income_net_loss_2006
# net_income_net_loss_2005
# import_quote
# export_quote
# trade_register_number
# isin_number_1
# bvd_id_number
# int_and_similar_expenses_2014
# int_and_similar_expenses_2013
# int_and_similar_expenses_2012
# int_and_similar_expenses_2011
# int_and_similar_expenses_2010
# int_and_similar_expenses_2009
# int_and_similar_expenses_2008
# int_and_similar_expenses_2007
# int_and_similar_expenses_2006
# int_and_similar_expenses_2005
# thof_int_2014
# thof_int_2013
# thof_int_2012
# thof_int_2011
# thof_int_2010
# thof_int_2009
# thof_int_2008
# thof_int_2007
# thof_int_2006
# thof_int_2005
# thof_int_on_shhldr_loans_2014
# thof_int_on_shhldr_loans_2013
# thof_int_on_shhldr_loans_2012
# thof_int_on_shhldr_loans_2011
# thof_int_on_shhldr_loans_2010
# thof_int_on_shhldr_loans_2009
# thof_int_on_shhldr_loans_2008
# thof_int_on_shhldr_loans_2007
# thof_int_on_shhldr_loans_2006
# thof_int_on_shhldr_loans_2005
# net_int_result_2014
# net_int_result_2013
# net_int_result_2012
# net_int_result_2011
# net_int_result_2010
# net_int_result_2009
# net_int_result_2008
# net_int_result_2007
# net_int_result_2006
# net_int_result_2005
# thof_int_fr_bank_deposits_2014
# thof_int_fr_bank_deposits_2013
# thof_int_fr_bank_deposits_2012
# thof_int_fr_bank_deposits_2011
# thof_int_fr_bank_deposits_2010
# thof_int_fr_bank_deposits_2009
# thof_int_fr_bank_deposits_2008
# thof_int_fr_bank_deposits_2007
# thof_int_fr_bank_deposits_2006
# thof_int_fr_bank_deposits_2005

# %% [markdown]
# # Combine files into 5 .csv fragments (additional.csv + 4 .csv fragments for everything else)

# %%
def combine_files(inputfolder, inputfilename_list, outputfilepath, colnames):
    df_combined = pd.DataFrame()
    for i, inputfilename in enumerate(inputfilename_list):
        print(f"Combining {i}: {inputfilename}")
        inputfilepath = Path(inputfolder / inputfilename)
        # The standard utf-8 encoding does not work, but cp1252 encoding does.
        df = pd.read_csv(inputfilepath, encoding='cp1252', low_memory=False, header=None, skip_blank_lines=True)
        # Drop the first column, which is just an index column
        df = df.iloc[:,1:]
        df.columns = colnames
        df['source_filename'] = inputfilename
        # Note that there seems to be many blank lines. But actually they have one column (306) with an int value. 
        # This is the column for US SIC codes, where a firm can have multiple SIC codes.
        # Fill in the missing values using the closest row above with non-missing values (forward-fill).
        df = df.fillna(method='ffill')
        df = df.replace('n.a.', np.NaN)
        df_combined = pd.concat([df_combined, df])
    if outputfilepath != '':
        df_combined.to_csv(outputfilepath, index=False)
        print("Saved file as:", outputfilepath)
        print("\n---\n")
    return df_combined

# %%
# Combine files into .csv fragments
# Treat additional.csv separately
# combine_files(inputfolder, inputfilename_list[1:2], Path(outputfolder_fragments / 'test.csv'), colnames)
combine_files(inputfolder, inputfilename_list[0:1], Path(outputfolder_fragments / 'additional.csv'), colnames)
combine_files(inputfolder, inputfilename_list[1:150], Path(outputfolder_fragments / 'dafne_export_fragment_1.csv'), colnames)
combine_files(inputfolder, inputfilename_list[150:300], Path(outputfolder_fragments / 'dafne_export_fragment_2.csv'), colnames)
combine_files(inputfolder, inputfilename_list[300:450], Path(outputfolder_fragments / 'dafne_export_fragment_3.csv'), colnames)
combine_files(inputfolder, inputfilename_list[450:], Path(outputfolder_fragments / 'dafne_export_fragment_4.csv'), colnames)
# Out:
# Combining 0: additional.csv
# Saved file as: C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\fragments\additional.csv
#
# ---
#
# Combining 0: Dafne_Export_1.xlsx.csv
# Combining 1: Dafne_Export_10.xlsx.csv
# Combining 2: Dafne_Export_11.xlsx.csv
# Combining 3: Dafne_Export_12.xlsx.csv
# Combining 4: Dafne_Export_13.xlsx.csv
# Combining 5: Dafne_Export_14.xlsx.csv
# Combining 6: Dafne_Export_15.xlsx.csv
# Combining 7: Dafne_Export_16.xlsx.csv
# Combining 8: Dafne_Export_17.xlsx.csv
# Combining 9: Dafne_Export_18.xlsx.csv
# Combining 10: Dafne_Export_19.xlsx.csv
# Combining 11: Dafne_Export_1_34 (1).xlsx.csv
# Combining 12: Dafne_Export_1_34 (10).xlsx.csv
# Combining 13: Dafne_Export_1_34 (11).xlsx.csv
# Combining 14: Dafne_Export_1_34 (12).xlsx.csv
# Combining 15: Dafne_Export_1_34 (13).xlsx.csv
# Combining 16: Dafne_Export_1_34 (14).xlsx.csv
# Combining 17: Dafne_Export_1_34 (15).xlsx.csv
# Combining 18: Dafne_Export_1_34 (16).xlsx.csv
# Combining 19: Dafne_Export_1_34 (17).xlsx.csv
# Combining 20: Dafne_Export_1_34 (18).xlsx.csv
# Combining 21: Dafne_Export_1_34 (19).xlsx.csv
# Combining 22: Dafne_Export_1_34 (2).xlsx.csv
# Combining 23: Dafne_Export_1_34 (20).xlsx.csv
# Combining 24: Dafne_Export_1_34 (21).xlsx.csv
# Combining 25: Dafne_Export_1_34 (22).xlsx.csv
# Combining 26: Dafne_Export_1_34 (23).xlsx.csv
# Combining 27: Dafne_Export_1_34 (24).xlsx.csv
# Combining 28: Dafne_Export_1_34 (25).xlsx.csv
# Combining 29: Dafne_Export_1_34 (26).xlsx.csv
# Combining 30: Dafne_Export_1_34 (27).xlsx.csv
# Combining 31: Dafne_Export_1_34 (28).xlsx.csv
# Combining 32: Dafne_Export_1_34 (29).xlsx.csv
# Combining 33: Dafne_Export_1_34 (3).xlsx.csv
# Combining 34: Dafne_Export_1_34 (30).xlsx.csv
# Combining 35: Dafne_Export_1_34 (31).xlsx.csv
# Combining 36: Dafne_Export_1_34 (32).xlsx.csv
# Combining 37: Dafne_Export_1_34 (33).xlsx.csv
# Combining 38: Dafne_Export_1_34 (34).xlsx.csv
# Combining 39: Dafne_Export_1_34 (4).xlsx.csv
# Combining 40: Dafne_Export_1_34 (5).xlsx.csv
# Combining 41: Dafne_Export_1_34 (6).xlsx.csv
# Combining 42: Dafne_Export_1_34 (7).xlsx.csv
# Combining 43: Dafne_Export_1_34 (8).xlsx.csv
# Combining 44: Dafne_Export_1_34 (9).xlsx.csv
# Combining 45: Dafne_Export_2.xlsx.csv
# Combining 46: Dafne_Export_20.xlsx.csv
# Combining 47: Dafne_Export_21.xlsx.csv
# Combining 48: Dafne_Export_22.xlsx.csv
# Combining 49: Dafne_Export_23.xlsx.csv
# Combining 50: Dafne_Export_24.xlsx.csv
# Combining 51: Dafne_Export_25.xlsx.csv
# Combining 52: Dafne_Export_26.xlsx.csv
# Combining 53: Dafne_Export_27.xlsx.csv
# Combining 54: Dafne_Export_273.xlsx.csv
# Combining 55: Dafne_Export_274.xlsx.csv
# Combining 56: Dafne_Export_275.xlsx.csv
# Combining 57: Dafne_Export_276.xlsx.csv
# Combining 58: Dafne_Export_277.xlsx.csv
# Combining 59: Dafne_Export_278.xlsx.csv
# Combining 60: Dafne_Export_279.xlsx.csv
# Combining 61: Dafne_Export_28.xlsx.csv
# Combining 62: Dafne_Export_280.xlsx.csv
# Combining 63: Dafne_Export_281.xlsx.csv
# Combining 64: Dafne_Export_282.xlsx.csv
# Combining 65: Dafne_Export_283.xlsx.csv
# Combining 66: Dafne_Export_284.xlsx.csv
# Combining 67: Dafne_Export_29.xlsx.csv
# Combining 68: Dafne_Export_3.xlsx.csv
# Combining 69: Dafne_Export_30.xlsx.csv
# Combining 70: Dafne_Export_31.xlsx.csv
# Combining 71: Dafne_Export_32.xlsx.csv
# Combining 72: Dafne_Export_33.xlsx.csv
# Combining 73: Dafne_Export_34.xlsx.csv
# Combining 74: Dafne_Export_35.xlsx.csv
# Combining 75: Dafne_Export_35_513 (1).xlsx.csv
# Combining 76: Dafne_Export_35_513 (10).xlsx.csv
# Combining 77: Dafne_Export_35_513 (100).xlsx.csv
# Combining 78: Dafne_Export_35_513 (101).xlsx.csv
# Combining 79: Dafne_Export_35_513 (102).xlsx.csv
# Combining 80: Dafne_Export_35_513 (103).xlsx.csv
# Combining 81: Dafne_Export_35_513 (104).xlsx.csv
# Combining 82: Dafne_Export_35_513 (105).xlsx.csv
# Combining 83: Dafne_Export_35_513 (106).xlsx.csv
# Combining 84: Dafne_Export_35_513 (107).xlsx.csv
# Combining 85: Dafne_Export_35_513 (108).xlsx.csv
# Combining 86: Dafne_Export_35_513 (109).xlsx.csv
# Combining 87: Dafne_Export_35_513 (11).xlsx.csv
# Combining 88: Dafne_Export_35_513 (110).xlsx.csv
# Combining 89: Dafne_Export_35_513 (111).xlsx.csv
# Combining 90: Dafne_Export_35_513 (112).xlsx.csv
# Combining 91: Dafne_Export_35_513 (113).xlsx.csv
# Combining 92: Dafne_Export_35_513 (114).xlsx.csv
# Combining 93: Dafne_Export_35_513 (115).xlsx.csv
# Combining 94: Dafne_Export_35_513 (116).xlsx.csv
# Combining 95: Dafne_Export_35_513 (117).xlsx.csv
# Combining 96: Dafne_Export_35_513 (118).xlsx.csv
# Combining 97: Dafne_Export_35_513 (119).xlsx.csv
# Combining 98: Dafne_Export_35_513 (12).xlsx.csv
# Combining 99: Dafne_Export_35_513 (120).xlsx.csv
# Combining 100: Dafne_Export_35_513 (121).xlsx.csv
# Combining 101: Dafne_Export_35_513 (122).xlsx.csv
# Combining 102: Dafne_Export_35_513 (123).xlsx.csv
# Combining 103: Dafne_Export_35_513 (124).xlsx.csv
# Combining 104: Dafne_Export_35_513 (125).xlsx.csv
# Combining 105: Dafne_Export_35_513 (126).xlsx.csv
# Combining 106: Dafne_Export_35_513 (127).xlsx.csv
# Combining 107: Dafne_Export_35_513 (128).xlsx.csv
# Combining 108: Dafne_Export_35_513 (129).xlsx.csv
# Combining 109: Dafne_Export_35_513 (13).xlsx.csv
# Combining 110: Dafne_Export_35_513 (130).xlsx.csv
# Combining 111: Dafne_Export_35_513 (131).xlsx.csv
# Combining 112: Dafne_Export_35_513 (132).xlsx.csv
# Combining 113: Dafne_Export_35_513 (133).xlsx.csv
# Combining 114: Dafne_Export_35_513 (134).xlsx.csv
# Combining 115: Dafne_Export_35_513 (135).xlsx.csv
# Combining 116: Dafne_Export_35_513 (136).xlsx.csv
# Combining 117: Dafne_Export_35_513 (137).xlsx.csv
# Combining 118: Dafne_Export_35_513 (138).xlsx.csv
# Combining 119: Dafne_Export_35_513 (139).xlsx.csv
# Combining 120: Dafne_Export_35_513 (14).xlsx.csv
# Combining 121: Dafne_Export_35_513 (140).xlsx.csv
# Combining 122: Dafne_Export_35_513 (141).xlsx.csv
# Combining 123: Dafne_Export_35_513 (142).xlsx.csv
# Combining 124: Dafne_Export_35_513 (143).xlsx.csv
# Combining 125: Dafne_Export_35_513 (144).xlsx.csv
# Combining 126: Dafne_Export_35_513 (145).xlsx.csv
# Combining 127: Dafne_Export_35_513 (146).xlsx.csv
# Combining 128: Dafne_Export_35_513 (147).xlsx.csv
# Combining 129: Dafne_Export_35_513 (148).xlsx.csv
# Combining 130: Dafne_Export_35_513 (149).xlsx.csv
# Combining 131: Dafne_Export_35_513 (15).xlsx.csv
# Combining 132: Dafne_Export_35_513 (150).xlsx.csv
# Combining 133: Dafne_Export_35_513 (151).xlsx.csv
# Combining 134: Dafne_Export_35_513 (152).xlsx.csv
# Combining 135: Dafne_Export_35_513 (153).xlsx.csv
# Combining 136: Dafne_Export_35_513 (154).xlsx.csv
# Combining 137: Dafne_Export_35_513 (155).xlsx.csv
# Combining 138: Dafne_Export_35_513 (156).xlsx.csv
# Combining 139: Dafne_Export_35_513 (157).xlsx.csv
# Combining 140: Dafne_Export_35_513 (158).xlsx.csv
# Combining 141: Dafne_Export_35_513 (159).xlsx.csv
# Combining 142: Dafne_Export_35_513 (16).xlsx.csv
# Combining 143: Dafne_Export_35_513 (160).xlsx.csv
# Combining 144: Dafne_Export_35_513 (161).xlsx.csv
# Combining 145: Dafne_Export_35_513 (162).xlsx.csv
# Combining 146: Dafne_Export_35_513 (163).xlsx.csv
# Combining 147: Dafne_Export_35_513 (164).xlsx.csv
# Combining 148: Dafne_Export_35_513 (165).xlsx.csv
# Saved file as: C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\fragments\dafne_export_fragment_1.csv
#
# ---
#
# Combining 0: Dafne_Export_35_513 (166).xlsx.csv
# Combining 1: Dafne_Export_35_513 (167).xlsx.csv
# Combining 2: Dafne_Export_35_513 (168).xlsx.csv
# Combining 3: Dafne_Export_35_513 (169).xlsx.csv
# Combining 4: Dafne_Export_35_513 (17).xlsx.csv
# Combining 5: Dafne_Export_35_513 (170).xlsx.csv
# Combining 6: Dafne_Export_35_513 (171).xlsx.csv
# Combining 7: Dafne_Export_35_513 (172).xlsx.csv
# Combining 8: Dafne_Export_35_513 (173).xlsx.csv
# Combining 9: Dafne_Export_35_513 (174).xlsx.csv
# Combining 10: Dafne_Export_35_513 (175).xlsx.csv
# Combining 11: Dafne_Export_35_513 (176).xlsx.csv
# Combining 12: Dafne_Export_35_513 (177).xlsx.csv
# Combining 13: Dafne_Export_35_513 (178).xlsx.csv
# Combining 14: Dafne_Export_35_513 (179).xlsx.csv
# Combining 15: Dafne_Export_35_513 (18).xlsx.csv
# Combining 16: Dafne_Export_35_513 (180).xlsx.csv
# Combining 17: Dafne_Export_35_513 (181).xlsx.csv
# Combining 18: Dafne_Export_35_513 (182).xlsx.csv
# Combining 19: Dafne_Export_35_513 (183).xlsx.csv
# Combining 20: Dafne_Export_35_513 (184).xlsx.csv
# Combining 21: Dafne_Export_35_513 (185).xlsx.csv
# Combining 22: Dafne_Export_35_513 (186).xlsx.csv
# Combining 23: Dafne_Export_35_513 (187).xlsx.csv
# Combining 24: Dafne_Export_35_513 (188).xlsx.csv
# Combining 25: Dafne_Export_35_513 (189).xlsx.csv
# Combining 26: Dafne_Export_35_513 (19).xlsx.csv
# Combining 27: Dafne_Export_35_513 (190).xlsx.csv
# Combining 28: Dafne_Export_35_513 (191).xlsx.csv
# Combining 29: Dafne_Export_35_513 (192).xlsx.csv
# Combining 30: Dafne_Export_35_513 (193).xlsx.csv
# Combining 31: Dafne_Export_35_513 (194).xlsx.csv
# Combining 32: Dafne_Export_35_513 (195).xlsx.csv
# Combining 33: Dafne_Export_35_513 (196).xlsx.csv
# Combining 34: Dafne_Export_35_513 (197).xlsx.csv
# Combining 35: Dafne_Export_35_513 (198).xlsx.csv
# Combining 36: Dafne_Export_35_513 (199).xlsx.csv
# Combining 37: Dafne_Export_35_513 (2).xlsx.csv
# Combining 38: Dafne_Export_35_513 (20).xlsx.csv
# Combining 39: Dafne_Export_35_513 (200).xlsx.csv
# Combining 40: Dafne_Export_35_513 (201).xlsx.csv
# Combining 41: Dafne_Export_35_513 (202).xlsx.csv
# Combining 42: Dafne_Export_35_513 (203).xlsx.csv
# Combining 43: Dafne_Export_35_513 (204).xlsx.csv
# Combining 44: Dafne_Export_35_513 (205).xlsx.csv
# Combining 45: Dafne_Export_35_513 (206).xlsx.csv
# Combining 46: Dafne_Export_35_513 (207).xlsx.csv
# Combining 47: Dafne_Export_35_513 (208).xlsx.csv
# Combining 48: Dafne_Export_35_513 (209).xlsx.csv
# Combining 49: Dafne_Export_35_513 (21).xlsx.csv
# Combining 50: Dafne_Export_35_513 (210).xlsx.csv
# Combining 51: Dafne_Export_35_513 (211).xlsx.csv
# Combining 52: Dafne_Export_35_513 (212).xlsx.csv
# Combining 53: Dafne_Export_35_513 (213).xlsx.csv
# Combining 54: Dafne_Export_35_513 (214).xlsx.csv
# Combining 55: Dafne_Export_35_513 (215).xlsx.csv
# Combining 56: Dafne_Export_35_513 (216).xlsx.csv
# Combining 57: Dafne_Export_35_513 (217).xlsx.csv
# Combining 58: Dafne_Export_35_513 (218).xlsx.csv
# Combining 59: Dafne_Export_35_513 (219).xlsx.csv
# Combining 60: Dafne_Export_35_513 (22).xlsx.csv
# Combining 61: Dafne_Export_35_513 (220).xlsx.csv
# Combining 62: Dafne_Export_35_513 (221).xlsx.csv
# Combining 63: Dafne_Export_35_513 (222).xlsx.csv
# Combining 64: Dafne_Export_35_513 (223).xlsx.csv
# Combining 65: Dafne_Export_35_513 (224).xlsx.csv
# Combining 66: Dafne_Export_35_513 (225).xlsx.csv
# Combining 67: Dafne_Export_35_513 (226).xlsx.csv
# Combining 68: Dafne_Export_35_513 (227).xlsx.csv
# Combining 69: Dafne_Export_35_513 (228).xlsx.csv
# Combining 70: Dafne_Export_35_513 (229).xlsx.csv
# Combining 71: Dafne_Export_35_513 (23).xlsx.csv
# Combining 72: Dafne_Export_35_513 (230).xlsx.csv
# Combining 73: Dafne_Export_35_513 (231).xlsx.csv
# Combining 74: Dafne_Export_35_513 (232).xlsx.csv
# Combining 75: Dafne_Export_35_513 (233).xlsx.csv
# Combining 76: Dafne_Export_35_513 (234).xlsx.csv
# Combining 77: Dafne_Export_35_513 (235).xlsx.csv
# Combining 78: Dafne_Export_35_513 (236).xlsx.csv
# Combining 79: Dafne_Export_35_513 (237).xlsx.csv
# Combining 80: Dafne_Export_35_513 (238).xlsx.csv
# Combining 81: Dafne_Export_35_513 (239).xlsx.csv
# Combining 82: Dafne_Export_35_513 (24).xlsx.csv
# Combining 83: Dafne_Export_35_513 (240).xlsx.csv
# Combining 84: Dafne_Export_35_513 (241).xlsx.csv
# Combining 85: Dafne_Export_35_513 (242).xlsx.csv
# Combining 86: Dafne_Export_35_513 (243).xlsx.csv
# Combining 87: Dafne_Export_35_513 (244).xlsx.csv
# Combining 88: Dafne_Export_35_513 (245).xlsx.csv
# Combining 89: Dafne_Export_35_513 (246).xlsx.csv
# Combining 90: Dafne_Export_35_513 (247).xlsx.csv
# Combining 91: Dafne_Export_35_513 (248).xlsx.csv
# Combining 92: Dafne_Export_35_513 (249).xlsx.csv
# Combining 93: Dafne_Export_35_513 (25).xlsx.csv
# Combining 94: Dafne_Export_35_513 (250).xlsx.csv
# Combining 95: Dafne_Export_35_513 (251).xlsx.csv
# Combining 96: Dafne_Export_35_513 (252).xlsx.csv
# Combining 97: Dafne_Export_35_513 (253).xlsx.csv
# Combining 98: Dafne_Export_35_513 (254).xlsx.csv
# Combining 99: Dafne_Export_35_513 (255).xlsx.csv
# Combining 100: Dafne_Export_35_513 (256).xlsx.csv
# Combining 101: Dafne_Export_35_513 (257).xlsx.csv
# Combining 102: Dafne_Export_35_513 (258).xlsx.csv
# Combining 103: Dafne_Export_35_513 (259).xlsx.csv
# Combining 104: Dafne_Export_35_513 (26).xlsx.csv
# Combining 105: Dafne_Export_35_513 (260).xlsx.csv
# Combining 106: Dafne_Export_35_513 (261).xlsx.csv
# Combining 107: Dafne_Export_35_513 (262).xlsx.csv
# Combining 108: Dafne_Export_35_513 (263).xlsx.csv
# Combining 109: Dafne_Export_35_513 (264).xlsx.csv
# Combining 110: Dafne_Export_35_513 (265).xlsx.csv
# Combining 111: Dafne_Export_35_513 (266).xlsx.csv
# Combining 112: Dafne_Export_35_513 (267).xlsx.csv
# Combining 113: Dafne_Export_35_513 (268).xlsx.csv
# Combining 114: Dafne_Export_35_513 (269).xlsx.csv
# Combining 115: Dafne_Export_35_513 (27).xlsx.csv
# Combining 116: Dafne_Export_35_513 (270).xlsx.csv
# Combining 117: Dafne_Export_35_513 (271).xlsx.csv
# Combining 118: Dafne_Export_35_513 (272).xlsx.csv
# Combining 119: Dafne_Export_35_513 (273).xlsx.csv
# Combining 120: Dafne_Export_35_513 (274).xlsx.csv
# Combining 121: Dafne_Export_35_513 (280).xlsx.csv
# Combining 122: Dafne_Export_35_513 (281).xlsx.csv
# Combining 123: Dafne_Export_35_513 (282).xlsx.csv
# Combining 124: Dafne_Export_35_513 (283).xlsx.csv
# Combining 125: Dafne_Export_35_513 (284).xlsx.csv
# Combining 126: Dafne_Export_35_513 (285).xlsx.csv
# Combining 127: Dafne_Export_35_513 (286).xlsx.csv
# Combining 128: Dafne_Export_35_513 (287).xlsx.csv
# Combining 129: Dafne_Export_35_513 (288).xlsx.csv
# Combining 130: Dafne_Export_35_513 (289).xlsx.csv
# Combining 131: Dafne_Export_35_513 (290).xlsx.csv
# Combining 132: Dafne_Export_35_513 (291).xlsx.csv
# Combining 133: Dafne_Export_35_513 (292).xlsx.csv
# Combining 134: Dafne_Export_35_513 (293).xlsx.csv
# Combining 135: Dafne_Export_35_513 (294).xlsx.csv
# Combining 136: Dafne_Export_35_513 (295).xlsx.csv
# Combining 137: Dafne_Export_35_513 (296).xlsx.csv
# Combining 138: Dafne_Export_35_513 (297).xlsx.csv
# Combining 139: Dafne_Export_35_513 (298).xlsx.csv
# Combining 140: Dafne_Export_35_513 (299).xlsx.csv
# Combining 141: Dafne_Export_35_513 (300).xlsx.csv
# Combining 142: Dafne_Export_35_513 (301).xlsx.csv
# Combining 143: Dafne_Export_35_513 (302).xlsx.csv
# Combining 144: Dafne_Export_35_513 (303).xlsx.csv
# Combining 145: Dafne_Export_35_513 (304).xlsx.csv
# Combining 146: Dafne_Export_35_513 (305).xlsx.csv
# Combining 147: Dafne_Export_35_513 (306).xlsx.csv
# Combining 148: Dafne_Export_35_513 (307).xlsx.csv
# Combining 149: Dafne_Export_35_513 (308).xlsx.csv
# Saved file as: C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\fragments\dafne_export_fragment_2.csv
#
# ---
#
# Combining 0: Dafne_Export_35_513 (309).xlsx.csv
# Combining 1: Dafne_Export_35_513 (310).xlsx.csv
# Combining 2: Dafne_Export_35_513 (311).xlsx.csv
# Combining 3: Dafne_Export_35_513 (312).xlsx.csv
# Combining 4: Dafne_Export_35_513 (313).xlsx.csv
# Combining 5: Dafne_Export_35_513 (314).xlsx.csv
# Combining 6: Dafne_Export_35_513 (315).xlsx.csv
# Combining 7: Dafne_Export_35_513 (316).xlsx.csv
# Combining 8: Dafne_Export_35_513 (317).xlsx.csv
# Combining 9: Dafne_Export_35_513 (318).xlsx.csv
# Combining 10: Dafne_Export_35_513 (319).xlsx.csv
# Combining 11: Dafne_Export_35_513 (320).xlsx.csv
# Combining 12: Dafne_Export_35_513 (321).xlsx.csv
# Combining 13: Dafne_Export_35_513 (322).xlsx.csv
# Combining 14: Dafne_Export_35_513 (323).xlsx.csv
# Combining 15: Dafne_Export_35_513 (324).xlsx.csv
# Combining 16: Dafne_Export_35_513 (325).xlsx.csv
# Combining 17: Dafne_Export_35_513 (326).xlsx.csv
# Combining 18: Dafne_Export_35_513 (327).xlsx.csv
# Combining 19: Dafne_Export_35_513 (328).xlsx.csv
# Combining 20: Dafne_Export_35_513 (329).xlsx.csv
# Combining 21: Dafne_Export_35_513 (330).xlsx.csv
# Combining 22: Dafne_Export_35_513 (331).xlsx.csv
# Combining 23: Dafne_Export_35_513 (332).xlsx.csv
# Combining 24: Dafne_Export_35_513 (333).xlsx.csv
# Combining 25: Dafne_Export_35_513 (334).xlsx.csv
# Combining 26: Dafne_Export_35_513 (335).xlsx.csv
# Combining 27: Dafne_Export_35_513 (336).xlsx.csv
# Combining 28: Dafne_Export_35_513 (337).xlsx.csv
# Combining 29: Dafne_Export_35_513 (338).xlsx.csv
# Combining 30: Dafne_Export_35_513 (339).xlsx.csv
# Combining 31: Dafne_Export_35_513 (340).xlsx.csv
# Combining 32: Dafne_Export_35_513 (341).xlsx.csv
# Combining 33: Dafne_Export_35_513 (342).xlsx.csv
# Combining 34: Dafne_Export_35_513 (343).xlsx.csv
# Combining 35: Dafne_Export_35_513 (344).xlsx.csv
# Combining 36: Dafne_Export_35_513 (345).xlsx.csv
# Combining 37: Dafne_Export_35_513 (346).xlsx.csv
# Combining 38: Dafne_Export_35_513 (347).xlsx.csv
# Combining 39: Dafne_Export_35_513 (348).xlsx.csv
# Combining 40: Dafne_Export_35_513 (349).xlsx.csv
# Combining 41: Dafne_Export_35_513 (350).xlsx.csv
# Combining 42: Dafne_Export_35_513 (351).xlsx.csv
# Combining 43: Dafne_Export_35_513 (352).xlsx.csv
# Combining 44: Dafne_Export_35_513 (353).xlsx.csv
# Combining 45: Dafne_Export_35_513 (354).xlsx.csv
# Combining 46: Dafne_Export_35_513 (355).xlsx.csv
# Combining 47: Dafne_Export_35_513 (356).xlsx.csv
# Combining 48: Dafne_Export_35_513 (357).xlsx.csv
# Combining 49: Dafne_Export_35_513 (358).xlsx.csv
# Combining 50: Dafne_Export_35_513 (359).xlsx.csv
# Combining 51: Dafne_Export_35_513 (360).xlsx.csv
# Combining 52: Dafne_Export_35_513 (361).xlsx.csv
# Combining 53: Dafne_Export_35_513 (362).xlsx.csv
# Combining 54: Dafne_Export_35_513 (363).xlsx.csv
# Combining 55: Dafne_Export_35_513 (364).xlsx.csv
# Combining 56: Dafne_Export_35_513 (365).xlsx.csv
# Combining 57: Dafne_Export_35_513 (366).xlsx.csv
# Combining 58: Dafne_Export_35_513 (367).xlsx.csv
# Combining 59: Dafne_Export_35_513 (368).xlsx.csv
# Combining 60: Dafne_Export_35_513 (369).xlsx.csv
# Combining 61: Dafne_Export_35_513 (370).xlsx.csv
# Combining 62: Dafne_Export_35_513 (371).xlsx.csv
# Combining 63: Dafne_Export_35_513 (372).xlsx.csv
# Combining 64: Dafne_Export_35_513 (373).xlsx.csv
# Combining 65: Dafne_Export_35_513 (374).xlsx.csv
# Combining 66: Dafne_Export_35_513 (375).xlsx.csv
# Combining 67: Dafne_Export_35_513 (376).xlsx.csv
# Combining 68: Dafne_Export_35_513 (377).xlsx.csv
# Combining 69: Dafne_Export_35_513 (378).xlsx.csv
# Combining 70: Dafne_Export_35_513 (379).xlsx.csv
# Combining 71: Dafne_Export_35_513 (380).xlsx.csv
# Combining 72: Dafne_Export_35_513 (381).xlsx.csv
# Combining 73: Dafne_Export_35_513 (382).xlsx.csv
# Combining 74: Dafne_Export_35_513 (383).xlsx.csv
# Combining 75: Dafne_Export_35_513 (384).xlsx.csv
# Combining 76: Dafne_Export_35_513 (385).xlsx.csv
# Combining 77: Dafne_Export_35_513 (386).xlsx.csv
# Combining 78: Dafne_Export_35_513 (387).xlsx.csv
# Combining 79: Dafne_Export_35_513 (388).xlsx.csv
# Combining 80: Dafne_Export_35_513 (389).xlsx.csv
# Combining 81: Dafne_Export_35_513 (390).xlsx.csv
# Combining 82: Dafne_Export_35_513 (391).xlsx.csv
# Combining 83: Dafne_Export_35_513 (392).xlsx.csv
# Combining 84: Dafne_Export_35_513 (393).xlsx.csv
# Combining 85: Dafne_Export_35_513 (394).xlsx.csv
# Combining 86: Dafne_Export_35_513 (395).xlsx.csv
# Combining 87: Dafne_Export_35_513 (396).xlsx.csv
# Combining 88: Dafne_Export_35_513 (397).xlsx.csv
# Combining 89: Dafne_Export_35_513 (398).xlsx.csv
# Combining 90: Dafne_Export_35_513 (399).xlsx.csv
# Combining 91: Dafne_Export_35_513 (400).xlsx.csv
# Combining 92: Dafne_Export_35_513 (401).xlsx.csv
# Combining 93: Dafne_Export_35_513 (402).xlsx.csv
# Combining 94: Dafne_Export_35_513 (403).xlsx.csv
# Combining 95: Dafne_Export_35_513 (404).xlsx.csv
# Combining 96: Dafne_Export_35_513 (405).xlsx.csv
# Combining 97: Dafne_Export_35_513 (406).xlsx.csv
# Combining 98: Dafne_Export_35_513 (407).xlsx.csv
# Combining 99: Dafne_Export_35_513 (408).xlsx.csv
# Combining 100: Dafne_Export_35_513 (409).xlsx.csv
# Combining 101: Dafne_Export_35_513 (410).xlsx.csv
# Combining 102: Dafne_Export_35_513 (411).xlsx.csv
# Combining 103: Dafne_Export_35_513 (412).xlsx.csv
# Combining 104: Dafne_Export_35_513 (413).xlsx.csv
# Combining 105: Dafne_Export_35_513 (414).xlsx.csv
# Combining 106: Dafne_Export_35_513 (415).xlsx.csv
# Combining 107: Dafne_Export_35_513 (416).xlsx.csv
# Combining 108: Dafne_Export_35_513 (417).xlsx.csv
# Combining 109: Dafne_Export_35_513 (418).xlsx.csv
# Combining 110: Dafne_Export_35_513 (419).xlsx.csv
# Combining 111: Dafne_Export_35_513 (420).xlsx.csv
# Combining 112: Dafne_Export_35_513 (421).xlsx.csv
# Combining 113: Dafne_Export_35_513 (422).xlsx.csv
# Combining 114: Dafne_Export_35_513 (423).xlsx.csv
# Combining 115: Dafne_Export_35_513 (424).xlsx.csv
# Combining 116: Dafne_Export_35_513 (425).xlsx.csv
# Combining 117: Dafne_Export_35_513 (426).xlsx.csv
# Combining 118: Dafne_Export_35_513 (427).xlsx.csv
# Combining 119: Dafne_Export_35_513 (428).xlsx.csv
# Combining 120: Dafne_Export_35_513 (429).xlsx.csv
# Combining 121: Dafne_Export_35_513 (430).xlsx.csv
# Combining 122: Dafne_Export_35_513 (431).xlsx.csv
# Combining 123: Dafne_Export_35_513 (432).xlsx.csv
# Combining 124: Dafne_Export_35_513 (433).xlsx.csv
# Combining 125: Dafne_Export_35_513 (434).xlsx.csv
# Combining 126: Dafne_Export_35_513 (435).xlsx.csv
# Combining 127: Dafne_Export_35_513 (436).xlsx.csv
# Combining 128: Dafne_Export_35_513 (437).xlsx.csv
# Combining 129: Dafne_Export_35_513 (438).xlsx.csv
# Combining 130: Dafne_Export_35_513 (439).xlsx.csv
# Combining 131: Dafne_Export_35_513 (440).xlsx.csv
# Combining 132: Dafne_Export_35_513 (441).xlsx.csv
# Combining 133: Dafne_Export_35_513 (442).xlsx.csv
# Combining 134: Dafne_Export_35_513 (443).xlsx.csv
# Combining 135: Dafne_Export_35_513 (444).xlsx.csv
# Combining 136: Dafne_Export_35_513 (445).xlsx.csv
# Combining 137: Dafne_Export_35_513 (446).xlsx.csv
# Combining 138: Dafne_Export_35_513 (447).xlsx.csv
# Combining 139: Dafne_Export_35_513 (448).xlsx.csv
# Combining 140: Dafne_Export_35_513 (449).xlsx.csv
# Combining 141: Dafne_Export_35_513 (450).xlsx.csv
# Combining 142: Dafne_Export_35_513 (451).xlsx.csv
# Combining 143: Dafne_Export_35_513 (452).xlsx.csv
# Combining 144: Dafne_Export_35_513 (453).xlsx.csv
# Combining 145: Dafne_Export_35_513 (454).xlsx.csv
# Combining 146: Dafne_Export_35_513 (455).xlsx.csv
# Combining 147: Dafne_Export_35_513 (456).xlsx.csv
# Combining 148: Dafne_Export_35_513 (457).xlsx.csv
# Combining 149: Dafne_Export_35_513 (458).xlsx.csv
# Saved file as: C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\fragments\dafne_export_fragment_3.csv
#
# ---
#
# Combining 0: Dafne_Export_35_513 (459).xlsx.csv
# Combining 1: Dafne_Export_35_513 (460).xlsx.csv
# Combining 2: Dafne_Export_35_513 (461).xlsx.csv
# Combining 3: Dafne_Export_35_513 (462).xlsx.csv
# Combining 4: Dafne_Export_35_513 (463).xlsx.csv
# Combining 5: Dafne_Export_35_513 (464).xlsx.csv
# Combining 6: Dafne_Export_35_513 (465).xlsx.csv
# Combining 7: Dafne_Export_35_513 (466).xlsx.csv
# Combining 8: Dafne_Export_35_513 (467).xlsx.csv
# Combining 9: Dafne_Export_35_513 (468).xlsx.csv
# Combining 10: Dafne_Export_35_513 (469).xlsx.csv
# Combining 11: Dafne_Export_35_513 (470).xlsx.csv
# Combining 12: Dafne_Export_35_513 (471).xlsx.csv
# Combining 13: Dafne_Export_35_513 (472).xlsx.csv
# Combining 14: Dafne_Export_35_513 (473).xlsx.csv
# Combining 15: Dafne_Export_35_513 (474).xlsx.csv
# Combining 16: Dafne_Export_35_513 (475).xlsx.csv
# Combining 17: Dafne_Export_35_513 (476).xlsx.csv
# Combining 18: Dafne_Export_35_513 (477).xlsx.csv
# Combining 19: Dafne_Export_35_513 (478).xlsx.csv
# Combining 20: Dafne_Export_35_513 (479).xlsx.csv
# Combining 21: Dafne_Export_35_513 (480).xlsx.csv
# Combining 22: Dafne_Export_35_513 (481).xlsx.csv
# Combining 23: Dafne_Export_35_513 (482).xlsx.csv
# Combining 24: Dafne_Export_36.xlsx.csv
# Combining 25: Dafne_Export_37.xlsx.csv
# Combining 26: Dafne_Export_38.xlsx.csv
# Combining 27: Dafne_Export_39.xlsx.csv
# Combining 28: Dafne_Export_4.xlsx.csv
# Combining 29: Dafne_Export_40.xlsx.csv
# Combining 30: Dafne_Export_41.xlsx.csv
# Combining 31: Dafne_Export_42.xlsx.csv
# Combining 32: Dafne_Export_43.xlsx.csv
# Combining 33: Dafne_Export_44.xlsx.csv
# Combining 34: Dafne_Export_45.xlsx.csv
# Combining 35: Dafne_Export_46.xlsx.csv
# Combining 36: Dafne_Export_47.xlsx.csv
# Combining 37: Dafne_Export_48.xlsx.csv
# Combining 38: Dafne_Export_481.xlsx.csv
# Combining 39: Dafne_Export_482.xlsx.csv
# Combining 40: Dafne_Export_483.xlsx.csv
# Combining 41: Dafne_Export_484.xlsx.csv
# Combining 42: Dafne_Export_485.xlsx.csv
# Combining 43: Dafne_Export_486.xlsx.csv
# Combining 44: Dafne_Export_487.xlsx.csv
# Combining 45: Dafne_Export_488.xlsx.csv
# Combining 46: Dafne_Export_489.xlsx.csv
# Combining 47: Dafne_Export_49.xlsx.csv
# Combining 48: Dafne_Export_490.xlsx.csv
# Combining 49: Dafne_Export_491.xlsx.csv
# Combining 50: Dafne_Export_492.xlsx.csv
# Combining 51: Dafne_Export_493.xlsx.csv
# Combining 52: Dafne_Export_494.xlsx.csv
# Combining 53: Dafne_Export_495.xlsx.csv
# Combining 54: Dafne_Export_496.xlsx.csv
# Combining 55: Dafne_Export_497.xlsx.csv
# Combining 56: Dafne_Export_498.xlsx.csv
# Combining 57: Dafne_Export_499.xlsx.csv
# Combining 58: Dafne_Export_5.xlsx.csv
# Combining 59: Dafne_Export_50.xlsx.csv
# Combining 60: Dafne_Export_500.xlsx.csv
# Combining 61: Dafne_Export_501.xlsx.csv
# Combining 62: Dafne_Export_502.xlsx.csv
# Combining 63: Dafne_Export_503.xlsx.csv
# Combining 64: Dafne_Export_504.xlsx.csv
# Combining 65: Dafne_Export_505.xlsx.csv
# Combining 66: Dafne_Export_506.xlsx.csv
# Combining 67: Dafne_Export_507.xlsx.csv
# Combining 68: Dafne_Export_508.xlsx.csv
# Combining 69: Dafne_Export_509.xlsx.csv
# Combining 70: Dafne_Export_51.xlsx.csv
# Combining 71: Dafne_Export_510.xlsx.csv
# Combining 72: Dafne_Export_511.xlsx.csv
# Combining 73: Dafne_Export_512.xlsx.csv
# Combining 74: Dafne_Export_513.xlsx.csv
# Combining 75: Dafne_Export_514.xlsx.csv
# Combining 76: Dafne_Export_515.xlsx.csv
# Combining 77: Dafne_Export_516.xlsx.csv
# Combining 78: Dafne_Export_517.xlsx.csv
# Combining 79: Dafne_Export_518.xlsx.csv
# Combining 80: Dafne_Export_519.xlsx.csv
# Combining 81: Dafne_Export_52.xlsx.csv
# Combining 82: Dafne_Export_520.xlsx.csv
# Combining 83: Dafne_Export_521.xlsx.csv
# Combining 84: Dafne_Export_522.xlsx.csv
# Combining 85: Dafne_Export_523.xlsx.csv
# Combining 86: Dafne_Export_524.xlsx.csv
# Combining 87: Dafne_Export_525.xlsx.csv
# Combining 88: Dafne_Export_526.xlsx.csv
# Combining 89: Dafne_Export_527.xlsx.csv
# Combining 90: Dafne_Export_528.xlsx.csv
# Combining 91: Dafne_Export_529.xlsx.csv
# Combining 92: Dafne_Export_53.xlsx.csv
# Combining 93: Dafne_Export_530.xlsx.csv
# Combining 94: Dafne_Export_531.xlsx.csv
# Combining 95: Dafne_Export_532.xlsx.csv
# Combining 96: Dafne_Export_533.xlsx.csv
# Combining 97: Dafne_Export_534.xlsx.csv
# Combining 98: Dafne_Export_535.xlsx.csv
# Combining 99: Dafne_Export_536.xlsx.csv
# Combining 100: Dafne_Export_537.xlsx.csv
# Combining 101: Dafne_Export_538.xlsx.csv
# Combining 102: Dafne_Export_539.xlsx.csv
# Combining 103: Dafne_Export_54.xlsx.csv
# Combining 104: Dafne_Export_540.xlsx.csv
# Combining 105: Dafne_Export_541.xlsx.csv
# Combining 106: Dafne_Export_542.xlsx.csv
# Combining 107: Dafne_Export_543.xlsx.csv
# Combining 108: Dafne_Export_544.xlsx.csv
# Combining 109: Dafne_Export_545.xlsx.csv
# Combining 110: Dafne_Export_546.xlsx.csv
# Combining 111: Dafne_Export_547.xlsx.csv
# Combining 112: Dafne_Export_548.xlsx.csv
# Combining 113: Dafne_Export_549.xlsx.csv
# Combining 114: Dafne_Export_55.xlsx.csv
# Combining 115: Dafne_Export_550.xlsx.csv
# Combining 116: Dafne_Export_551.xlsx.csv
# Combining 117: Dafne_Export_552.xlsx.csv
# Combining 118: Dafne_Export_553.xlsx.csv
# Combining 119: Dafne_Export_554.xlsx.csv
# Combining 120: Dafne_Export_555.xlsx.csv
# Combining 121: Dafne_Export_556.xlsx.csv
# Combining 122: Dafne_Export_557.xlsx.csv
# Combining 123: Dafne_Export_558.xlsx.csv
# Combining 124: Dafne_Export_559.xlsx.csv
# Combining 125: Dafne_Export_56.xlsx.csv
# Combining 126: Dafne_Export_560.xlsx.csv
# Combining 127: Dafne_Export_561.xlsx.csv
# Combining 128: Dafne_Export_562.xlsx.csv
# Combining 129: Dafne_Export_563.xlsx.csv
# Combining 130: Dafne_Export_564.xlsx.csv
# Combining 131: Dafne_Export_565.xlsx.csv
# Combining 132: Dafne_Export_566.xlsx.csv
# Combining 133: Dafne_Export_567.xlsx.csv
# Combining 134: Dafne_Export_568.xlsx.csv
# Combining 135: Dafne_Export_569.xlsx.csv
# Combining 136: Dafne_Export_57.xlsx.csv
# Combining 137: Dafne_Export_570.xlsx.csv
# Combining 138: Dafne_Export_571.xlsx.csv
# Combining 139: Dafne_Export_572.xlsx.csv
# Combining 140: Dafne_Export_573.xlsx.csv
# Combining 141: Dafne_Export_574.xlsx.csv
# Combining 142: Dafne_Export_575.xlsx.csv
# Combining 143: Dafne_Export_576.xlsx.csv
# Combining 144: Dafne_Export_577.xlsx.csv
# Combining 145: Dafne_Export_578.xlsx.csv
# Combining 146: Dafne_Export_579.xlsx.csv
# Combining 147: Dafne_Export_58.xlsx.csv
# Combining 148: Dafne_Export_580.xlsx.csv
# Combining 149: Dafne_Export_581.xlsx.csv
# Combining 150: Dafne_Export_582.xlsx.csv
# Combining 151: Dafne_Export_583.xlsx.csv
# Combining 152: Dafne_Export_584.xlsx.csv
# Combining 153: Dafne_Export_585.xlsx.csv
# Combining 154: Dafne_Export_586.xlsx.csv
# Combining 155: Dafne_Export_587.xlsx.csv
# Combining 156: Dafne_Export_588.xlsx.csv
# Combining 157: Dafne_Export_589.xlsx.csv
# Combining 158: Dafne_Export_59.xlsx.csv
# Combining 159: Dafne_Export_590.xlsx.csv
# Combining 160: Dafne_Export_591.xlsx.csv
# Combining 161: Dafne_Export_592.xlsx.csv
# Combining 162: Dafne_Export_593.xlsx.csv
# Combining 163: Dafne_Export_594.xlsx.csv
# Combining 164: Dafne_Export_595.xlsx.csv
# Combining 165: Dafne_Export_596.xlsx.csv
# Combining 166: Dafne_Export_597.xlsx.csv
# Combining 167: Dafne_Export_598.xlsx.csv
# Combining 168: Dafne_Export_599.xlsx.csv
# Combining 169: Dafne_Export_6.xlsx.csv
# Combining 170: Dafne_Export_60.xlsx.csv
# Combining 171: Dafne_Export_600.xlsx.csv
# Combining 172: Dafne_Export_601.xlsx.csv
# Combining 173: Dafne_Export_602.xlsx.csv
# Combining 174: Dafne_Export_603.xlsx.csv
# Combining 175: Dafne_Export_604.xlsx.csv
# Combining 176: Dafne_Export_605.xlsx.csv
# Combining 177: Dafne_Export_606.xlsx.csv
# Combining 178: Dafne_Export_607.xlsx.csv
# Combining 179: Dafne_Export_608.xlsx.csv
# Combining 180: Dafne_Export_609.xlsx.csv
# Combining 181: Dafne_Export_61.xlsx.csv
# Combining 182: Dafne_Export_610.xlsx.csv
# Combining 183: Dafne_Export_611.xlsx.csv
# Combining 184: Dafne_Export_612.xlsx.csv
# Combining 185: Dafne_Export_613.xlsx.csv
# Combining 186: Dafne_Export_614.xlsx.csv
# Combining 187: Dafne_Export_615.xlsx.csv
# Combining 188: Dafne_Export_616.xlsx.csv
# Combining 189: Dafne_Export_617.xlsx.csv
# Combining 190: Dafne_Export_618.xlsx.csv
# Combining 191: Dafne_Export_619.xlsx.csv
# Combining 192: Dafne_Export_62.xlsx.csv
# Combining 193: Dafne_Export_620.xlsx.csv
# Combining 194: Dafne_Export_621.xlsx.csv
# Combining 195: Dafne_Export_622.xlsx.csv
# Combining 196: Dafne_Export_623.xlsx.csv
# Combining 197: Dafne_Export_624.xlsx.csv
# Combining 198: Dafne_Export_625.xlsx.csv
# Combining 199: Dafne_Export_626.xlsx.csv
# Combining 200: Dafne_Export_627.xlsx.csv
# Combining 201: Dafne_Export_628.xlsx.csv
# Combining 202: Dafne_Export_629.xlsx.csv
# Combining 203: Dafne_Export_63.xlsx.csv
# Combining 204: Dafne_Export_630.xlsx.csv
# Combining 205: Dafne_Export_631.xlsx.csv
# Combining 206: Dafne_Export_632.xlsx.csv
# Combining 207: Dafne_Export_64.xlsx.csv
# Combining 208: Dafne_Export_65.xlsx.csv
# Combining 209: Dafne_Export_66.xlsx.csv
# Combining 210: Dafne_Export_67.xlsx.csv
# Combining 211: Dafne_Export_68.xlsx.csv
# Combining 212: Dafne_Export_69.xlsx.csv
# Combining 213: Dafne_Export_7.xlsx.csv
# Combining 214: Dafne_Export_70.xlsx.csv
# Combining 215: Dafne_Export_71.xlsx.csv
# Combining 216: Dafne_Export_72.xlsx.csv
# Combining 217: Dafne_Export_73.xlsx.csv
# Combining 218: Dafne_Export_74.xlsx.csv
# Combining 219: Dafne_Export_75.xlsx.csv
# Combining 220: Dafne_Export_76.xlsx.csv
# Combining 221: Dafne_Export_77.xlsx.csv
# Combining 222: Dafne_Export_78.xlsx.csv
# Combining 223: Dafne_Export_79.xlsx.csv
# Combining 224: Dafne_Export_8.xlsx.csv
# Combining 225: Dafne_Export_80.xlsx.csv
# Combining 226: Dafne_Export_81.xlsx.csv
# Combining 227: Dafne_Export_9.xlsx.csv
# Saved file as: C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\fragments\dafne_export_fragment_4.csv
#
# ---
#                                            company_name  crefo_number  \
# 0                           Mocca-X-Press GmbH & Co. KG  2.011802e+09
# 1     MOCC Mobile Office Competence Center Be- teili...  8.250344e+09
# 2     MOCC Mobile Office Competence Center Be- teili...  8.250344e+09
# 3                                      MOC-Consult GmbH  7.330599e+09
# 4                                      MOC-Consult GmbH  7.330599e+09
# ...                                                 ...           ...
# 6158               Kunkel Consulting International GmbH  6.270118e+09
# 6159               Kunkel Consulting International GmbH  6.270118e+09
# 6160           Langlotz Glas- und Gebäudereinigung GmbH  7.210131e+09
# 6161                                    Lumitronic GmbH  5.230279e+09
# 6162                                    Lumitronic GmbH  5.230279e+09
#
#       gkz_administrative_region_code  gkz_borough_code  \
# 0                               11.0           11000.0
# 1                                9.0            9171.0
# 2                                9.0            9171.0
# 3                                8.0            8111.0
# 4                                8.0            8111.0
# ...                              ...               ...
# 6158                             6.0            6431.0
# 6159                             6.0            6431.0
# 6160                             8.0            8317.0
# 6161                             5.0            5166.0
# 6162                             5.0            5166.0
#
#      wz_2008_pri_actv_cd_1_digit wz_2008_pri_actv_cd_3_digits  \
# 0                              I                          I56
# 1                              M                          M70
# 2                              M                          M70
# 3                              M                          M70
# 4                              M                          M70
# ...                          ...                          ...
# 6158                           M                          M71
# 6159                           M                          M71
# 6160                           N                          N81
# 6161                           F                          F43
# 6162                           F                          F43
#
#      original_date_of_incorporation listed_delisted_unlisted peer_group_name  \
# 0                        11/09/2006      Nicht börsennotiert       I561 - SM
# 1                              2006      Nicht börsennotiert       M701 - SM
# 2                              2006      Nicht börsennotiert       M701 - SM
# 3                        06/07/2000      Nicht börsennotiert       M702 - LA
# 4                        06/07/2000      Nicht börsennotiert       M702 - LA
# ...                             ...                      ...             ...
# 6158                     08/10/2003                 Unlisted       M711 - LA
# 6159                     08/10/2003                 Unlisted       M711 - LA
# 6160                     08/03/2011                 Unlisted       N812 - LA
# 6161                     01/10/1996                 Unlisted       F432 - LA
# 6162                     01/10/1996                 Unlisted       F432 - LA
#
#                                  peer_group_description  ...  \
# 0     Restaurants, Gaststätten, Imbissstuben, Cafés,...  ...
# 1     Verwaltung und Führung von Unternehmen und Bet...  ...
# 2     Verwaltung und Führung von Unternehmen und Bet...  ...
# 3     Public-Relations- und Unternehmensberatung (GR...  ...
# 4     Public-Relations- und Unternehmensberatung (GR...  ...
# ...                                                 ...  ...
# 6158  Architectural and engineering activities and r...  ...
# 6159  Architectural and engineering activities and r...  ...
# 6160              Cleaning activities (large companies)  ...
# 6161  Electrical, plumbing and other construction in...  ...
# 6162  Electrical, plumbing and other construction in...  ...
#
#      thof_int_fr_bank_deposits_2013 thof_int_fr_bank_deposits_2012  \
# 0                              n.v.                           n.v.
# 1                              n.v.                           n.v.
# 2                              n.v.                           n.v.
# 3                              n.v.                           n.v.
# 4                              n.v.                           n.v.
# ...                             ...                            ...
# 6158                            NaN                            NaN
# 6159                            NaN                            NaN
# 6160                            NaN                            NaN
# 6161                            NaN                            NaN
# 6162                            NaN                            NaN
#
#      thof_int_fr_bank_deposits_2011 thof_int_fr_bank_deposits_2010  \
# 0                              n.v.                           n.v.
# 1                              n.v.                           n.v.
# 2                              n.v.                           n.v.
# 3                              n.v.                           n.v.
# 4                              n.v.                           n.v.
# ...                             ...                            ...
# 6158                            NaN                            NaN
# 6159                            NaN                            NaN
# 6160                            NaN                            NaN
# 6161                            NaN                            NaN
# 6162                            NaN                            NaN
#
#      thof_int_fr_bank_deposits_2009 thof_int_fr_bank_deposits_2008  \
# 0                              n.v.                           n.v.
# 1                              n.v.                           n.v.
# 2                              n.v.                           n.v.
# 3                              n.v.                           n.v.
# 4                              n.v.                           n.v.
# ...                             ...                            ...
# 6158                            NaN                            NaN
# 6159                            NaN                            NaN
# 6160                            NaN                            NaN
# 6161                            NaN                            NaN
# 6162                            NaN                            NaN
#
#      thof_int_fr_bank_deposits_2007 thof_int_fr_bank_deposits_2006  \
# 0                              n.v.                           n.v.
# 1                              n.v.                           n.v.
# 2                              n.v.                           n.v.
# 3                              n.v.                           n.v.
# 4                              n.v.                           n.v.
# ...                             ...                            ...
# 6158                            NaN                            NaN
# 6159                            NaN                            NaN
# 6160                            NaN                            NaN
# 6161                            NaN                            NaN
# 6162                            NaN                            NaN
#
#      thof_int_fr_bank_deposits_2005                     source_filename
# 0                              n.v.  Dafne_Export_35_513 (459).xlsx.csv
# 1                              n.v.  Dafne_Export_35_513 (459).xlsx.csv
# 2                              n.v.  Dafne_Export_35_513 (459).xlsx.csv
# 3                              n.v.  Dafne_Export_35_513 (459).xlsx.csv
# 4                              n.v.  Dafne_Export_35_513 (459).xlsx.csv
# ...                             ...                                 ...
# 6158                            NaN             Dafne_Export_9.xlsx.csv
# 6159                            NaN             Dafne_Export_9.xlsx.csv
# 6160                            NaN             Dafne_Export_9.xlsx.csv
# 6161                            NaN             Dafne_Export_9.xlsx.csv
# 6162                            NaN             Dafne_Export_9.xlsx.csv
#
# [1356443 rows x 464 columns]

# %% [markdown]
# # Combine fragments into 1 combined file, and save as both .csv and .dta

# %%
def combine_fragments(inputfolder, inputfilename_list, outputfolder, outputfilename):
    df_combined = pd.DataFrame()
    for i, inputfilename in enumerate(inputfilename_list):
        print(f"Combining {i}: {inputfilename}")
        inputfilepath = Path(inputfolder / inputfilename)
        df = pd.read_csv(inputfilepath, low_memory=False)
        df_combined = pd.concat([df_combined, df])
    if outputfolder != '':
        outputfilepath = Path(outputfolder / str(outputfilename+'.csv'))
        df_combined.to_csv(outputfilepath, index=False)
        print("Saved file as:", outputfilepath)
        outputfilepath = Path(outputfolder / str(outputfilename+'.dta'))
        df_combined.to_stata(outputfilepath, write_index=False)
        print("Saved file as:", outputfilepath)
        print("\n---\n")
    return df_combined

# %%
# Get list of fragments to combine
fragmentfilename_list = os.listdir(outputfolder_fragments)
print("Number of files:", len(fragmentfilename_list))
fragmentfilename_list
# Out:
# Number of files: 5
# ['additional.csv',
#  'dafne_export_fragment_1.csv',
#  'dafne_export_fragment_2.csv',
#  'dafne_export_fragment_3.csv',
#  'dafne_export_fragment_4.csv']

# %%
# Combine fragments into .csv and .dta files
# combine_fragments(outputfolder_fragments, fragmentfilename_list, outputfolder_combined, 'test')
combine_fragments(outputfolder_fragments, fragmentfilename_list, outputfolder_combined, 'dafne_export_combined_20230217')
# Out:
# Combining 0: additional.csv
# Combining 1: dafne_export_fragment_1.csv
# Combining 2: dafne_export_fragment_2.csv
# Combining 3: dafne_export_fragment_3.csv
# Combining 4: dafne_export_fragment_4.csv
# Saved file as: C:\Users\jasonjia\Dropbox\projects\combine_dafne_data\output\combined\dafne_export_combined_20230217.csv
